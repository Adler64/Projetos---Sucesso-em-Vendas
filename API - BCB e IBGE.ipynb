# %%
import pandas as pd 
import json 
import requests
from functools import reduce

# %%
api = 'https://api.bcb.gov.br/dados/serie/bcdata.sgs.11/dados?formato=json'

# %%
#Taxa SELIC - Série Temporal
selic = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.1178/dados?formato=json')
selic.rename(columns = {'valor' : 'Taxa SELIC'}, inplace = True)

# %%
# Produto Interno Bruto - PIB (Anual) (R$)

# PIB Corrente
pib_cor = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.1207/dados?formato=json') 
pib_cor.rename(columns = {'valor' : 'PIB Corrente'}, inplace = True)

# PIB per Capita
pib_per = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21775/dados?formato=json') 
pib_per.rename(columns = {'valor' : 'PIB per Capita'}, inplace = True)

# PIB Agro - Variação Real Anual
pib_agro = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.7327/dados?formato=json') 
pib_agro.rename(columns = {'valor' : 'PIB Agronegócios (%)'}, inplace = True)

# PIB Indústria - Variação Real Anual
pib_ind = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.7328/dados?formato=json')
pib_ind.rename(columns = {'valor' : 'PIB Indústria (%)'}, inplace = True)

# PIB Serviços - Variação Real Anual
pib_ser = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.7329/dados?formato=json')
pib_ser.rename(columns = {'valor' : 'PIB Serviços (%)'}, inplace = True)

#Concatenação dos Dataframes
dfs = [pib_cor, pib_per, pib_agro, pib_ind, pib_ser]
pibs = reduce(lambda  left,right: pd.merge(left,right,on=['data'],
                                            how='outer'), dfs)

# %%
#Outros Indicadores do PIB 

# PIB Mensal Corrente (R$ Milhões)
pib_men = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.4380/dados?formato=json')
pib_men.rename(columns = {'valor' : 'PIB Mensal Corrente'}, inplace = True)

# IBC-Br (Mensal) (Índice)
ibcbr = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.24363/dados?formato=json')
ibcbr.rename(columns = {'valor' : 'IBC-Br'}, inplace = True)

# IBC-Br (Mensal) (Índice)
ibcbr2 = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.24364/dados?formato=json')
ibcbr2.rename(columns = {'valor' : 'IBC-Br - Com Ajuste Sazonal'}, inplace = True)

#Concatenação dos Dataframes
dfs = [pib_men, ibcbr, ibcbr2]
pibs2 = reduce(lambda  left,right: pd.merge(left,right,on=['data'],
                                            how='outer'), dfs)

# %%
#PIB - Análise Trimestral (Índice) (Trimestral)

# PIB Trimestral - Agro
pib_tri_agro = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.22083/dados?formato=json')
pib_tri_agro.rename(columns = {'valor' : 'PIB Trimestral - Agro'}, inplace = True)

# PIB Trimestral - Indústria
pib_tri_ind = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.22084/dados?formato=json')
pib_tri_ind.rename(columns = {'valor' : 'PIB Trimestral - Indústria'}, inplace = True)

# PIB Trimestral - Extrativa Mineira
pib_tri_ext = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.22085/dados?formato=json')
pib_tri_ext.rename(columns = {'valor' : 'PIB Trimestral - Extrativa Mineira'}, inplace = True)

# PIB Trimestral - Transformação
pib_tri_tra = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.22086/dados?formato=json')
pib_tri_tra.rename(columns = {'valor' : 'PIB Trimestral - Transformação'}, inplace = True)

# PIB Trimestral - Construção Civil
pib_tri_con = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.22087/dados?formato=json')
pib_tri_con.rename(columns = {'valor' : 'PIB Trimestral - Construção Civil'}, inplace = True)

# PIB Trimestral - Serviços
pib_tri_ser = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.22089/dados?formato=json')
pib_tri_ser.rename(columns = {'valor' : 'PIB Trimestral - Serviços'}, inplace = True)

# PIB Trimestral - Comércio
pib_tri_com = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.22090/dados?formato=json')
pib_tri_com.rename(columns = {'valor' : 'PIB Trimestral - Comércio'}, inplace = True)

# PIB Trimestral - Transporte
pib_tri_trans = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.22091/dados?formato=json')
pib_tri_trans.rename(columns = {'valor' : 'PIB Trimestral - Transporte'}, inplace = True)

# PIB Trimestral - Atividades Imobiliárias
pib_tri_imo = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.22096/dados?formato=json')
pib_tri_imo.rename(columns = {'valor' : 'PIB Trimestral - At. Imobiliárias'}, inplace = True)

# PIB Trimestral - PIB A preços de Mercado
pib_tri = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.22099/dados?formato=json')
pib_tri.rename(columns = {'valor' : 'PIB Trimestral - À Preços de Mercado'}, inplace = True)

# PIB Trimestral - Consumo das Famílias
pib_tri_fam = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.22100/dados?formato=json')
pib_tri_fam.rename(columns = {'valor' : 'PIB Trimestral - Consumo Familiar'}, inplace = True)

# PIB Trimestral - Consumo do Governo
pib_tri_gov = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.22101/dados?formato=json')
pib_tri_gov.rename(columns = {'valor' : 'PIB Trimestral - Consumo Governo'}, inplace = True)

# PIB Trimestral - Exportação
pib_tri_exp = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.22103/dados?formato=json')
pib_tri_exp.rename(columns = {'valor' : 'PIB Trimestral - Exportação'}, inplace = True)

# PIB Trimestral - Importação
pib_tri_imp = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.22104/dados?formato=json')
pib_tri_imp.rename(columns = {'valor' : 'PIB Trimestral - Importação'}, inplace = True)

#Concatenação dos Dataframes
dfs = [pib_tri_imp,pib_tri_exp,pib_tri_gov,pib_tri_fam,pib_tri,pib_tri_imo,pib_tri_trans,pib_tri_com,pib_tri_ser,pib_tri_con,pib_tri_tra,pib_tri_ext,pib_tri_ind,pib_tri_agro]
pibs_tri = reduce(lambda  left,right: pd.merge(left,right,on=['data'],
                                            how='outer'), dfs)

# %%
# Índices de Confiança - Fecomercio

#Índice de Confiança do Consumidor
con_consumidor = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.4393/dados?formato=json') 
con_consumidor.rename(columns = {'valor' : 'Índice de Confiança do Consumidor'}, inplace = True)

#Índice de Condições Econômicas Atuais
con_atual = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.4394/dados?formato=json') 
con_atual.rename(columns = {'valor' : 'Índice de Condições Econômicas Atuais'}, inplace = True)

#Índice de Expectativas Futuras
con_futuro = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.4395/dados?formato=json') 
con_futuro.rename(columns = {'valor' : 'Índice de Expectativas Futuras'}, inplace = True)

#Concatenação dos Dataframes
dfs = [con_consumidor, con_atual, con_futuro]
confianca = reduce(lambda  left,right: pd.merge(left,right,on=['data'],
                                            how='outer'), dfs)

# %%
#PMC - Total
pmc = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.1455/dados?formato=json') 
pmc.rename(columns = {'valor' : 'PMC - Geral'}, inplace = True)
pmc = pmc.to_excel("C:\\Users\\SV - João Victor\\Sucesso em Vendas\\Gestão de Resultados - Documentos\\10- Desenvolvimento\\Inflação\\PMC.xlsx", sheet_name  = "teste")

# %%
#Indicadores de Produção Industrial - IBGE

#Produção Geral
prod_geral = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21859/dados?formato=json') 
prod_geral.rename(columns = {"valor" : "Produção Geral"}, inplace = True)

#Produção de Bens de Capital
prod_capital = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21863/dados?formato=json') 
prod_capital.rename(columns = {"valor" : "Produção de Bens de Capital"}, inplace = True)

#Produção de Bens de Consumo
prod_con = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21865/dados?formato=json') 
prod_con.rename(columns = {"valor" : "Produção de Bens de Consumo"}, inplace = True)

#Produção de Bens de Consumo Duráveis
prod_con_du = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21866/dados?formato=json') 
prod_con_du.rename(columns = {"valor" : "Produção de Bens de Consumo Duráveis"}, inplace = True)

dfs = [prod_geral, prod_con, prod_con_du, prod_capital]
Produção = reduce(lambda  left,right: pd.merge(left,right,on=['data'],
                                            how='outer'), dfs)

# %%
#Índice de Preços ao Consumidor Amplo (IPCA) - IBGE

#IPCA Geral
ipca = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.433/dados?formato=json') 
ipca.rename(columns = {"valor" : "IPCA"}, inplace = True)

#IPCA - Alimentação e Bebidas
ipca_ali = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.1635/dados?formato=json') 
ipca_ali.rename(columns = {"valor" : "IPCA - Alimentação e Bebidas"}, inplace = True)

#IPCA - Habitação
ipca_hab = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.1636/dados?formato=json') 
ipca_hab.rename(columns = {"valor" : "IPCA - Habitação"}, inplace = True)

#IPCA - Artigos de Residência
ipca_res = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.1637/dados?formato=json') 
ipca_res.rename(columns = {"valor" : "IPCA - Artigos de Residência"}, inplace = True)

#IPCA - Vestuário
ipca_ves = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.1638/dados?formato=json') 
ipca_ves.rename(columns = {"valor" : "IPCA - Vestuário"}, inplace = True)

#IPCA - Transportes
ipca_com = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.1639/dados?formato=json') 
ipca_com.rename(columns = {"valor" : "IPCA - Transportes"}, inplace = True)

#IPCA - Transportes
ipca_saude = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.1641/dados?formato=json') 
ipca_saude.rename(columns = {"valor" : "IPCA - Saúde"}, inplace = True)

#IPCA - Despesas Pessoais
ipca_des = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.1642/dados?formato=json') 
ipca_des.rename(columns = {"valor" : "IPCA - Despesas Pessoais"}, inplace = True)

#IPCA - Educação
ipca_edu = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.1643/dados?formato=json') 
ipca_edu.rename(columns = {"valor" : "IPCA - Educação"}, inplace = True)

#IPCA - Serviços
ipca_ser = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.10844/dados?formato=json') 
ipca_ser.rename(columns = {"valor" : "IPCA - Serviços"}, inplace = True)

dfs = [ipca_edu, ipca_des, ipca_saude, ipca_com, ipca_ves, ipca_res, ipca_hab, ipca_ali, ipca, ipca_ser]
ipcas = reduce(lambda  left,right: pd.merge(left,right,on=['data'],
                                            how='outer'), dfs)

# %%
#Agregados Monetários - Base Monetária

#Papel Moeda em Circulação
#base_cir = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.1780/dados?formato=json') 
#base_cir.rename(columns = {"Papel Moeda em Circulação"}, inplace = True)

#Reservas Bancárias
#base_res = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.1781/dados?formato=json') 
#base_res.rename(columns = {"Reservas Bancárias"}, inplace = True)

#Base Monetária Restrita
#base_restri = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.1782/dados?formato=json') 
#base_restri.rename(columns = {"Base Monetária Restrita"}, inplace = True)

#dfs = [base_cir, base_res,]
#base_monetaria = reduce(lambda  left,right: pd.merge(left,right,on=['data'],
                                            #how='outer'), dfs)

# %% [markdown]
# #Base Monetária - Operações Monetárias
#
# #Operações com Títulos Públicos Federais
# ope_tit = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.1789/dados?formato=json')
# ope_tit.rename(columns = {"valor" : "Operações de Títulos Públicos"}, inplace = True)
#
# #Tesouro Nacional - Conta
# ope_tes = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.1790/dados?formato=json')
# ope_tes.rename(columns = {"valor" : "Tesouro Nacional"}, inplace = True)
#
# #Operações com o Setor Externo
# ope_ext = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.1791/dados?formato=json')
# ope_ext.rename(columns = {"valor" : "Operações com Setor Externo"}, inplace = True)
#
# #Depósitos de Instituições Financeiras
# ope_dep = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.1795/dados?formato=json')
# ope_dep.rename(columns = {"valor" : "Depósitos de Instituições Financeiras"}, inplace = True)
#
# #Redesconto
# ope_red = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.12481/dados?formato=json')
# ope_red.rename(columns = {"valor" : "Redesconto"}, inplace = True)
#
# #Operações com títulos públicos federais – mercado primário
# ope_pri = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.29003/dados?formato=json')
# ope_pri.rename(columns = {"valor" : "Operações de Títulos Públicos - Mercado Primário"}, inplace = True)
#
# #Operações com títulos públicos federais – mercado secundário
# ope_sec = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.29005/dados?formato=json')
# ope_sec.rename(columns = {"valor" : "Operações de Títulos Públicos - Mercado Secundário"}, inplace = True)
#
# dfs = [ope_sec, ope_pri, ope_red, ope_dep, ope_ext, ope_tes,ope_tit]
# operacoes_monetarias = reduce(lambda  left,right: pd.merge(left,right,on=['data'],
#                                             how='outer'), dfs)

# %%
#Base Monetária - Meios de Pagamento

#Papel Moeda em Poder do Público
papel = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.27783/dados?formato=json') 
papel.rename(columns = {"valor" : "Papel Moeda em Poder do Público"}, inplace = True)

#Depósitos à Vista
depo = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.27784/dados?formato=json') 
depo.rename(columns = {"valor" : "Depositos a Vista"}, inplace = True)

#M1
m1 = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.27785/dados?formato=json') 
m1.rename(columns = {"valor" : "M1"}, inplace = True)

dfs = [papel, depo, m1]
meios_pagamento = reduce(lambda  left,right: pd.merge(left,right,on=['data'],
                                            how='outer'), dfs)

# %%
#Compulsório - Saldo Total
depo = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.17633/dados?formato=json') 
depo.rename(columns = {"valor" : "Compulsório Total"}, inplace = True)

# %%
#Setor Externo - Reservas Internacionais

#Reservas Internacionais - Mensal
res_inter = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.3546/dados?formato=json') 
res_inter.rename(columns = {"valor" : "Reservas Internacionais"}, inplace = True)

# %%
#Crédito Banco Central - Saldos de Crédito (Mensal) (R$ Milhões)

#Saldo de Crédito Total
cred_total = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.20539/dados?formato=json') 
cred_total.rename(columns = {"valor" : "Saldo de Crédito Total"}, inplace = True)

#Saldo de Crédito PJ
cred_pj = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.20540/dados?formato=json') 
cred_pj.rename(columns = {"valor" : "Saldo de Crédito - PJ"}, inplace = True)

#Saldo de Crédito PF
cred_pf = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.20541/dados?formato=json') 
cred_pf.rename(columns = {"valor" : "Saldo de Crédito - PF"}, inplace = True)

#Saldo de Grandes Empresas
cred_grandes = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.27702/dados?formato=json') 
cred_grandes.rename(columns = {"valor" : "Saldo de Crédito - Grandes Empresas"}, inplace = True)

#Saldo de Micro, Pequenas e Médias
cred_micro = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.27701/dados?formato=json') 
cred_micro.rename(columns = {"valor" : "Saldo de Crédito - Micro, Pequenas e Médias"}, inplace = True)

dfs = [cred_total, cred_pj, cred_pf,cred_micro, cred_grandes]
saldo_creditos = reduce(lambda  left,right: pd.merge(left,right,on=['data'],
                                            how='outer'), dfs)

# %%
#Crédito Banco Central - Saldos de Crédito de Recursos Livres (Mensal) (R$ Milhões)


#Saldo Total
saldo = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.20542/dados?formato=json') 
saldo.rename(columns = {"valor" : "Saldo Total"}, inplace = True)

#Saldo Total PJ
saldo_pj = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.20543/dados?formato=json') 
saldo_pj.rename(columns = {"valor" : "Saldo Total - PJ"}, inplace = True)

#Saldo Total PF
saldo_pf = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.20570/dados?formato=json') 
saldo_pf.rename(columns = {"valor" : "Saldo Total - PF"}, inplace = True)

dfs = [saldo, saldo_pj, saldo_pf]
saldo_creditos2 = reduce(lambda  left,right: pd.merge(left,right,on=['data'],
                                            how='outer'), dfs)

# %%
#ICC - Índice de Custo do Crédito (Mensal) (% a.a.)

#ICC - Total
icc = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.25354/dados?formato=json') 
icc.rename(columns = {"valor" : "ICC - Total"}, inplace = True)

#ICC - PJ
icc_pj= pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.25355/dados?formato=json') 
icc_pj.rename(columns = {"valor" : "ICC - PJ"}, inplace = True)

#ICC - PF
icc_pf= pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.25356/dados?formato=json') 
icc_pf.rename(columns = {"valor" : "ICC - PF"}, inplace = True)


dfs = [icc, icc_pj, icc_pf]
icc = reduce(lambda  left,right: pd.merge(left,right,on=['data'],
                                            how='outer'), dfs)

# %%
#Atrasos e Inadimplências - Recursos Livres (Mensal) (%)

#Inadimplência Total (%)
inad = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21085/dados?formato=json') 
inad.rename(columns = {"valor" : "Inadimplência - Total"}, inplace = True)

#Inadimplência - PJ (%)
inad_pj = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21086/dados?formato=json') 
inad_pj.rename(columns = {"valor" : "Inadimplência - PJ"}, inplace = True)

#Inadimplência - PF (%)
inad_pf = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21112/dados?formato=json') 
inad_pf.rename(columns = {"valor" : "Inadimplência - PF"}, inplace = True)

#Inadimplência - Grandes Empresas (%)
inad_gra = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.27704/dados?formato=json') 
inad_gra.rename(columns = {"valor" : "Inadimplência - Grandes Empresas"}, inplace = True)

#Inadimplência - MPMe (%)
inad_MPMe = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.27706/dados?formato=json') 
inad_MPMe.rename(columns = {"valor" : "Inadimplência - MPMe"}, inplace = True)

#Atrasos da carteira entre 15 e 90 dias - Total (%)
atrasos = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21006/dados?formato=json') 
atrasos.rename(columns = {"valor" : "Atrasos - Total"}, inplace = True)

#Atrasos da carteira entre 15 e 90 dias - PJ (%)
atrasos_pj = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21007/dados?formato=json') 
atrasos_pj.rename(columns = {"valor" : "Atrasos - PJ"}, inplace = True)

#Atrasos da carteira entre 15 e 90 dias - PF (%)
atrasos_pf = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21033/dados?formato=json') 
atrasos_pf.rename(columns = {"valor" : "Atrasos - PF"}, inplace = True)

#Endividamento Familiar (%) (Mensal)
endiv = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.29037/dados?formato=json') 
endiv.rename(columns = {"valor" : "Endividamento Familiar"}, inplace = True)

dfs = [inad, inad_pj, inad_pf, inad_gra, inad_MPMe, atrasos, atrasos_pj, atrasos_pf, endiv]
atrasos = reduce(lambda  left,right: pd.merge(left,right,on=['data'],
                                            how='outer'), dfs)

# %%
#Indicadores de Oferta e Demanda de Crédito (Trimestral) (Pontos)

#Demanda Esperada - Grandes Empresas
dem_e_gra = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21380/dados?formato=json') 
dem_e_gra.rename(columns = {"valor" : "Grandes Empresas - Demanda Esperada"}, inplace = True)

#Demanda Observada - Grandes Empresas
dem_o_gra = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21381/dados?formato=json') 
dem_o_gra.rename(columns = {"valor" : "Grandes Empresas - Demanda Observada"}, inplace = True)

#Demanda Esperada - MPME
dem_e_MPME  = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21382/dados?formato=json') 
dem_e_MPME.rename(columns = {"valor" : "MPME - Demanda Esperada"}, inplace = True)

#Demanda Observada - MPME
dem_o_MPME  = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21383/dados?formato=json') 
dem_o_MPME.rename(columns = {"valor" : "MPME - Demanda Observada"}, inplace = True)

#Demanda Esperada - Consumo
dem_e_con  = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21384/dados?formato=json') 
dem_e_con.rename(columns = {"valor" : "Consumo - Demanda Esperada"}, inplace = True)

#Demanda Observada - Consumo
dem_o_con  = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21385/dados?formato=json') 
dem_o_con.rename(columns = {"valor" : "Consumo - Demanda Observada"}, inplace = True)

#Demanda Esperada - Habitacional
dem_e_hab  = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21386/dados?formato=json') 
dem_e_hab.rename(columns = {"valor" : "Habitacional - Demanda Esperada"}, inplace = True)

#Demanda Observada - Habitacional
dem_o_hab  = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21387/dados?formato=json') 
dem_o_hab.rename(columns = {"valor" : "Habitacional - Demanda Observada"}, inplace = True)

#Oferta Esperada - Grandes Empresas
ofe_e_gra  = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21388/dados?formato=json') 
ofe_e_gra.rename(columns = {"valor" : "Grandes Empresas - Oferta Esperada"}, inplace = True)

#Oferta Observada - Grandes Empresas
ofe_o_gra  = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21389/dados?formato=json') 
ofe_o_gra.rename(columns = {"valor" : "Grandes Empresas - Oferta Observada"}, inplace = True)

#Oferta Esperada - MPME 
ofe_e_MPME   = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21390/dados?formato=json') 
ofe_e_MPME.rename(columns = {"valor" : "MPME - Oferta Esperada"}, inplace = True)

#Oferta Observada - MPME 
ofe_o_MPME   = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21391/dados?formato=json') 
ofe_o_MPME.rename(columns = {"valor" : "MPME - Oferta Observada"}, inplace = True)

#Oferta Esperada - Consumo 
ofe_e_con   = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21392/dados?formato=json') 
ofe_e_con.rename(columns = {"valor" : "Consumo - Oferta Esperada"}, inplace = True)

#Oferta Observada - Consumo 
ofe_o_con   = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21393/dados?formato=json') 
ofe_o_con.rename(columns = {"valor" : "Consumo - Oferta Observada"}, inplace = True)

#Oferta Esperada - Habitacional 
ofe_e_hab   = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21394/dados?formato=json') 
ofe_e_hab.rename(columns = {"valor" : "Habitacional - Oferta Esperada"}, inplace = True)

#Oferta Observada - Habitacional 
ofe_o_hab   = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21395/dados?formato=json') 
ofe_o_hab.rename(columns = {"valor" : "Habitacional - Oferta Observada"}, inplace = True)

dfs = [ofe_o_hab ,ofe_e_hab ,ofe_o_con,ofe_e_con,ofe_o_MPME,ofe_e_MPME,ofe_o_gra,ofe_e_gra,dem_o_hab,dem_e_hab,dem_o_con,dem_e_con,dem_o_MPME,dem_e_MPME,dem_o_gra,dem_e_gra]
oferta = reduce(lambda  left,right: pd.merge(left,right,on=['data'],
                                            how='outer'), dfs)

# %%
#Crédito Banco Central - Saldo por Segmento da Economia (R$ Milhões)

#Indústria

#Saldo Total
saldo = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.20542/dados?formato=json') 
saldo.rename(columns = {"valor" : "Saldo Total"}, inplace = True)

#Saldo Agropecuário Total
saldo_agro = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.22027/dados?formato=json') 
saldo_agro.rename(columns = {"valor" : "Agropecuário"}, inplace = True)

#Saldo Industrial Total
saldo_ind = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.22027/dados?formato=json') 
saldo_ind.rename(columns = {"valor" : "Industrial"}, inplace = True)

#Saldo Serviços Total
saldo_ser = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.22044/dados?formato=json') 
saldo_ser.rename(columns = {"valor" : "Serviços"}, inplace = True)

#Saldo Industrial - Construção
saldo_cons = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.22030/dados?formato=json') 
saldo_cons.rename(columns = {"valor" : "Industrial - Construção"}, inplace = True)

#Saldo Industrial - Alimentos
saldo_ali = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.27743/dados?formato=json') 
saldo_ali.rename(columns = {"valor" : "Industrial - Alimentos"}, inplace = True)

#Saldo Industrial - Têxtil, Vestuário, Couro e Calçados
saldo_vest = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.27745/dados?formato=json') 
saldo_vest.rename(columns = {"valor" : "Industrial - Vestuário"}, inplace = True)

#Saldo Industrial - Papel e Celulose
saldo_pap = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.27746/dados?formato=json') 
saldo_pap.rename(columns = {"valor" : "Industrial - Papel"}, inplace = True)

#Saldo Industrial - Metalúrgica e Siderúrgica
saldo_met = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.27748/dados?formato=json') 
saldo_met.rename(columns = {"valor" : "Industrial - Metalúrgica"}, inplace = True)

#Saldo Industrial - Química e Farmacêutica
saldo_qui = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.27722/dados?formato=json') 
saldo_qui.rename(columns = {"valor" : "Industrial - Farmacêutica"}, inplace = True)

#Saldo Industrial - Bens de Capital
saldo_cap = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.27723/dados?formato=json') 
saldo_cap.rename(columns = {"valor" : "Indústria - Bens de Capital"}, inplace = True)

#Saldo Industrial - Obras de Infraestrutura
saldo_inf = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.27725/dados?formato=json') 
saldo_inf.rename(columns = {"valor" : "Indústria - Infraestrutura"}, inplace = True)

#Saldo Industrial - Bens Duráveis
saldo_dur = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.27728/dados?formato=json') 
saldo_dur.rename(columns = {"valor" : "Indústria - Não Duráveis"}, inplace = True)

#Saldo Serviços - Transporte
saldo_tra = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.22037/dados?formato=json') 
saldo_tra.rename(columns = {"valor" : "Serviços - Transporte"}, inplace = True)

#Saldo Serviços - Comércio
saldo_com = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.22036/dados?formato=json') 
saldo_com.rename(columns = {"valor" : "Serviços - Comércio"}, inplace = True)

#Saldo Serviços - Varejo Bens Não Duráveis
saldo_varn = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.22036/dados?formato=json') 
saldo_varn.rename(columns = {"valor" : "Serviços - Varejo Bens Não Duráveis"}, inplace = True)

#Saldo Serviços - Varejo Bens Duráveis
saldo_vard = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.27733/dados?formato=json') 
saldo_vard.rename(columns = {"valor" : "Serviços - Varejo Bens Duráveis"}, inplace = True)

#Saldo Serviços - Atacado
saldo_ata= pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.27734/dados?formato=json') 
saldo_ata.rename(columns = {"valor" : "Serviços - Atacado"}, inplace = True)

#Saldo Serviços - Veículos
saldo_ata= pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.27735/dados?formato=json') 
saldo_ata.rename(columns = {"valor" : "Serviços - Veículos"}, inplace = True)

#Saldo Serviços - Imobiliários
saldo_imo= pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.27738/dados?formato=json') 
saldo_imo.rename(columns = {"valor" : "Serviços - Imobiliários"}, inplace = True)

#Saldo Serviços - Informação e Comunicação
saldo_info= pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.27739/dados?formato=json') 
saldo_info.rename(columns = {"valor" : "Serviços - Info e Comunicação"}, inplace = True)


dfs = [saldo_info, saldo_imo, saldo_ata, saldo_vard, saldo_varn, saldo_tra, saldo_com, saldo_dur, saldo_inf, saldo_qui,saldo_met,saldo_pap,saldo_vest, saldo_ali,saldo_cons, saldo_ser, saldo_ind, saldo_agro, saldo]
credito_segmento = reduce(lambda  left,right: pd.merge(left,right,on=['data'],
                                            how='outer'), dfs)

# %%
#Outros Indicadores de Preço

#Índice Geral de Preços do Mercado - IGP-M
igpm= pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.189/dados?formato=json') 
igpm.rename(columns = {"valor" : "IGP-M"}, inplace = True)

#Índice Nacional de Custo da Construção - INCC
incc= pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.192/dados?formato=json') 
incc.rename(columns = {"valor" : "INCC"}, inplace = True)

dfs = [igpm, incc]
preços = reduce(lambda  left,right: pd.merge(left,right,on=['data'],
                                            how='outer'), dfs)

# %%
#Cestas Básicas por Região

#CB - São Paulo
cb_sp= pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.7493/dados?formato=json') 
cb_sp.rename(columns = {"valor" : "Cesta Básica - São Paulo"}, inplace = True)

#CB - Rio de Janeiro
cb_rj= pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.7491/dados?formato=json') 
cb_rj.rename(columns = {"valor" : "Cesta Básica - Rio de Janeiro"}, inplace = True)

#CB - Curitiba
cb_cur= pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.7483/dados?formato=json') 
cb_cur.rename(columns = {"valor" : "Cesta Básica - Curitiba"}, inplace = True)

#CB - Belo Horizonte
cb_bh= pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.7481/dados?formato=json') 
cb_bh.rename(columns = {"valor" : "Cesta Básica - Belo Horizonte"}, inplace = True)

#CB - Salvador
cb_sal= pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.7492/dados?formato=json') 
cb_sal.rename(columns = {"valor" : "Cesta Básica - Salvador"}, inplace = True)

#CB - Brasília
cb_br= pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.7482/dados?formato=json') 
cb_br.rename(columns = {"valor" : "Cesta Básica - Brasília"}, inplace = True)

dfs = [cb_br, cb_rj, cb_sp, cb_sal, cb_cur, cb_bh]
cestas = reduce(lambda  left,right: pd.merge(left,right,on=['data'],
                                            how='outer'), dfs)

# %%
#Câmbio

#Dólar
dol = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.1/dados?formato=json') 
dol.rename(columns = {"valor" : "Dólar"}, inplace = True)

#Euro
eur = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21619/dados?formato=json') 
eur.rename(columns = {"valor" : "Euro"}, inplace = True)

#Iene
ien = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21621/dados?formato=json') 
ien.rename(columns = {"valor" : "Iene"}, inplace = True)

#Libra Esterlina
libra = pd.read_json('https://api.bcb.gov.br/dados/serie/bcdata.sgs.21623/dados?formato=json') 
libra.rename(columns = {"valor" : "Libra Esterlina"}, inplace = True)

dfs = [libra, dol, eur, ien]
cambio = reduce(lambda  left,right: pd.merge(left,right,on=['data'],
                                            how='outer'), dfs)

# %%
#Função de Extração para Séries Temporais pela API do IBGE

anos = ['2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021']
tudo = []
per = [] 
for ano in anos:
    periodos = [ano + str(i).zfill(2) for i in range (1, 13)]
    q_periodos = '|'.join(periodos) + '|'
    per.append(q_periodos)
per = ''.join(per)
periodos = ['2022' + str(i).zfill(2) for i in range (1, 13)]
q_periodos = '|'.join(periodos)
per = per + q_periodos

# %%
#Pesquisa Mensal de Comércio Varejista - Volume de Vendas - Número-índice

atividades = ['2759', '90671','103154','2759','31555','31556','103158']
lista2 = []

for atividade in atividades:
    response = requests.get(url = 'https://servicodados.ibge.gov.br/api/v3/agregados/8187/periodos/'+per+'/variaveis/11706?localidades=N1[all]|N3[all]&classificacao=11046[56734]|85['+atividade+']')
    resultados = response.json()[0]['resultados']
    for resultado in resultados:
        series = resultado['series']
        for serie in series:
            dados = pd.DataFrame.from_dict(serie['serie'], orient='index', columns = ['PMC - Volume de Vendas'])
            dados['Nível Regional'] = serie['localidade']['nivel']['nome']
            dados['Região'] = serie['localidade']['nome']
            dados['Categoria'] = list(resultado['classificacoes'][0]['categoria'].values())[0]
            dados = dados.reset_index().rename(columns = {'index': 'Período'})
            dados['Período'] = pd.to_datetime(dados['Período'], format = '%Y%m')
            dados['Atividade'] = list(resultado['classificacoes'][1]['categoria'].values())[0]

            # Anexa o conjunto de dados do loop atual na lista
            lista2.append(dados)
    pmc_volume = pd.concat(lista2)

# %%
#Pesquisa Mensal de Comércio Varejista - Receita Nominal - Número-índice

atividades = ['2759', '90671','103154','2759','31555','31556','103158']
lista2 = []

for atividade in atividades:
    response = requests.get(url = 'https://servicodados.ibge.gov.br/api/v3/agregados/8187/periodos/'+per+'/variaveis/11706?localidades=N3[all]&classificacao=11046[56733]|85['+atividade+']')
    resultados = response.json()[0]['resultados']
    for resultado in resultados:
        series = resultado['series']
        for serie in series:
            dados = pd.DataFrame.from_dict(serie['serie'], orient='index', columns = ['PMC - Receita Nominal'])
            dados['Nível Regional'] = serie['localidade']['nivel']['nome']
            dados['Região'] = serie['localidade']['nome']
            dados['Categoria'] = list(resultado['classificacoes'][0]['categoria'].values())[0]
            dados = dados.reset_index().rename(columns = {'index': 'Período'})
            dados['Período'] = pd.to_datetime(dados['Período'], format = '%Y%m')
            dados['Atividade'] = list(resultado['classificacoes'][1]['categoria'].values())[0]

            # Anexa o conjunto de dados do loop atual na lista
            lista2.append(dados)
    pmc_receita = pd.concat(lista2)

# %%
#Pesquisa Mensal de Serviços - Volume de Vendas - Número-índice

atividades = ['107071', '106869','106874','31399', '106876', '31426']
lista2 = []

for atividade in atividades:
    response = requests.get(url = 'https://servicodados.ibge.gov.br/api/v3/agregados/8164/periodos/'+per+'/variaveis/11621?localidades=N3[all]&classificacao=12355['+atividade
    +']')
    resultados = response.json()[0]['resultados']
    for resultado in resultados:
        series = resultado['series']
        for serie in series:
            dados = pd.DataFrame.from_dict(serie['serie'], orient='index', columns = ['PMS - Volume de Vendas'])
            dados['Nível Regional'] = serie['localidade']['nivel']['nome']
            dados['Região'] = serie['localidade']['nome']
            dados['Categoria'] = list(resultado['classificacoes'][0]['categoria'].values())[0]
            dados = dados.reset_index().rename(columns = {'index': 'Período'})
            dados['Período'] = pd.to_datetime(dados['Período'], format = '%Y%m')
            dados['Atividade'] = list(resultado['classificacoes'][1]['categoria'].values())[0]

            # Anexa o conjunto de dados do loop atual na lista
            lista2.append(dados)
    pms_volume = pd.concat(lista2)

# %%
#Pesquisa Mensal de Serviços - Volume de Vendas - Número-índice

atividades = ['107071','106869','106870','31396','106874','31397','39321','39322','31399','31400','31421','106876','31422','31423','31424','31425','31426']
lista2 = []

for atividade in atividades:
    response = requests.get(url = 'https://servicodados.ibge.gov.br/api/v3/agregados/8162/periodos/'+per+'/variaveis/11621?localidades=N1[all]&classificacao=11046[56725]|12355['+atividade+']')
    resultados = response.json()[0]['resultados']
    for resultado in resultados:
        series = resultado['series']
        for serie in series:
            dados = pd.DataFrame.from_dict(serie['serie'], orient='index', columns = ['PMS - Receita Nominal'])
            dados['Nível Regional'] = serie['localidade']['nivel']['nome']
            dados['Região'] = serie['localidade']['nome']
            dados['Categoria'] = list(resultado['classificacoes'][0]['categoria'].values())[0]
            dados = dados.reset_index().rename(columns = {'index': 'Período'})
            dados['Período'] = pd.to_datetime(dados['Período'], format = '%Y%m')
            dados['Atividade'] = list(resultado['classificacoes'][1]['categoria'].values())[0]

            # Anexa o conjunto de dados do loop atual na lista
            lista2.append(dados)
    pms_receita = pd.concat(lista2)

# %%
#Escrevendo Arquivos em Excel
Destino = "C:\\Users\\SV - João Victor\\Sucesso em Vendas\\Gestão de Resultados - 10- Desenvolvimento\\Dados Econômicos\\"
with pd.ExcelWriter(path = Destino + "Dados Econômicos - Extração API.xlsx", engine = 'xlsxwriter', engine_kwargs = {'options' : {'strings_to_formulas': False}}) as update:
    credito_segmento = credito_segmento.to_excel(update, sheet_name = "Saldos Crédito - Por Segmento")
    saldo_creditos2 = saldo_creditos2.to_excel(update, sheet_name = "Crédito - Recursos Livres", index = False)
    saldo_creditos = saldo_creditos.to_excel(update, sheet_name = "Crédito - Geral", index = False)
    meios_pagamento = meios_pagamento.to_excel(update, sheet_name = "Meios de Pagamento", index = False)
    ipcas = ipcas.to_excel(update, sheet_name = "IPCA- Por Segmento", index = False)
    Produção = Produção.to_excel(update, sheet_name = "Produção Industrial", index = False)
    confianca = confianca.to_excel(update, sheet_name = "Índices de Confiança", index = False)
    cambio = cambio.to_excel(update, sheet_name = "Taxas de Câmbio", index = False)
    cestas = cestas.to_excel(update, sheet_name = "Cestas Básicas", index = False)
    preços = preços.to_excel(update, sheet_name = "índices de Preço", index = False)
    pibs_tri = pibs_tri.to_excel(update, sheet_name = "PIB Trimestral", index = False)
    pibs2 = pibs2.to_excel(update, sheet_name = "PIB Mensal Corrente", index = False)
    pibs = pibs.to_excel(update, sheet_name = "PIB", index = False)
    selic = selic.to_excel(update, sheet_name = "Taxa Selic", index = False)
    pmc_volume = pmc_volume.to_excel(update, index = False, sheet_name = "PMC - Volume de Vendas")
    pmc_receita = pmc_receita.to_excel(update, index = False, sheet_name = 'PMC - Receita de Vendas Nominal')
    pms_receita = pms_receita.to_excel(update, index = False, sheet_name = "PMS - Receita de Vendas Nominal")
    pms_volume = pms_volume.to_excel(update, index = False, sheet_name = "PMS - Volume de Vendas")
    oferta = oferta.to_excel(update, index = False, sheet_name = "Oferta e Demanda de Crédito")
    atrasos = atrasos.to_excel(update, index = False, sheet_name = "Inadimplências e Atrasos")
    icc = icc.to_excel(update, index = False, sheet_name = "Custo do Crédito")
