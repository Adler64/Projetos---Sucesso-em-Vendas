# %% [markdown]
# Streamlined Data Ingestion with Pandas

# %%
import pandas as pd
import requests
import json
import statsmodels 
import plotly

# %%
#Requisição do Access Token
url = "https://api.rd.services/auth/token?client_id=716ccadc-fbad-47e6-b9c6-13da491d0843&client_secret=ece007d7ecd44e4eb750f5912edb4668&refresh_token=MK-OfKEw8QvDZxnYkI4CdIhJ0CK6L0VJxqIi6tOPNn4"

payload={}
headers = {
  'client_id': '716ccadc-fbad-47e6-b9c6-13da491d0843',
  'client_secret': 'ece007d7ecd44e4eb750f5912edb4668',
  'refresh_token': 'MK-OfKEw8QvDZxnYkI4CdIhJ0CK6L0VJxqIi6tOPNn4',
  'Cookie': '__rdsid=7a56931cff7f914cd8f546f70117c191'
}

response = requests.request("POST",url, headers=headers, data=payload)
token = response.json()['access_token']
access_token = 'Bearer ' + token
access_token
# Out:
# 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..CiGCnOYPQgn1G55jvqa448n49vNVtdJFOzQ3dwUaUBwrY7rm77tbK42LHAWBQm81ZFCuxn0cG2Whn84-z778_M5ynIFXZlY6HgdSj2FUZu_XFFDFlZDsXUniJ5w-7SKk0Sz8aBNE0VE9f_7l5qAMx4vNXtuR_7hpxe_49mSqhD5RN5xncQs-5RYFk7g0Ozq0qUCPLEs5oREYSusZhF-525301IJEhC6R7quCH5oafiWtWsGGLXKG-MdJ83Y60cM6Wup1rAsqYK5blEYjcjMMSwM-0K4uLIdXTRFFp1ER-PWzB5GmYG1zBOu_fBxe0sjtNhZ4eXFSZaRU8t5hm7fWkg'

# %%
#Consulta de Segmentação Geral

url = "https://api.rd.services/platform/segmentations"

headers = {
    "Accept": "application/json",

    "Authorization": access_token
}
params = {
    'page': '1',
    'page_size':'125' 
}

lista = []
page = 1
while True:
    general_response = requests.get(url, headers=headers, params = {'page': str(page), "page_size": "125"})
    r = general_response.json()
    if len(r['segmentations'])== 0:
       break
    lista.append(pd.DataFrame.from_dict(r['segmentations']))
    page = page + 1
segmentações = pd.concat(lista)
segmentações.drop(['created_at', 'updated_at', 'standard','process_status','links'], axis =1, inplace = True)

segmentações = segmentações.to_excel('C:\\Users\\SV - João Victor\\Sucesso em Vendas\\Gestão de Resultados - Documentos\\Projetos\\02 - Report por Área\Marketing\\Power BI - Redes Sociais\\RDStation\\DIM_Segmentações.xlsx')

# %% [markdown]
# Lista total dos IDs e suas segmentações
#
# segmentações.set_index('id').T.to_dict('list')

# %% [markdown]
# #ID das segmentações em forma de lista.
#
# segmentações.drop(['name'], axis =1, inplace = True)
# ids = segmentações['id'].to_list()
# ids_2 = []
# for id in ids:
#     ids_2.append(str(id))
# ids_2

# %%
#IDs das segmentações requisitadas

seg_landing = {6514872: ['Acesso_Página = 10 Prinícios Básicos...'],
                6514880: ['Acesso_Página = 10 desculpas para não treinar...'],
                6514886: ['Acesso_Página = 106% da meta na viacerta...'],
                6514893: ['Acesso_Página = 11 maneiras de melhorar a prospecção...'],
                6514896: ['Acesso_Página = 187% a mais de vendedores'],
                6514915: ['Acesso_Página = 3 formas de treinar gerentes'],
                6514936: ['Acesso_Página = 3 Formas de treinar gerentes (2)'],
                6514975: ['Acesso_Página = 33% de crescimento no faturamento'],
                6514992: ['Acesso_Página = 33% de crescimento no faturamento (2)'],
                6515104: ['Acesso_Páginas = Todas'],
                6515234: ['Acesso_Página = 37% de crescimento'],
                6515237: ['Acesso_Página = 4 pontos essenciais para conseguir resultados'],
                6515242: ['Acesso_Página = 4 passos essenciais para conseguir resultados (2)'],
                6515274: ['Acesso_Página = 5  dicas para gerentes'],
                6515282: ['Acesso_Página = 5 problemas gerados por'],
                6515293: ['Acesso_Páginas = 5 problemas que estragam'],
                6515299: ['Acesso_Página = 6 fatores críticos'],
                6515313: ['Acesso_Página = 6 estratégias para reter'],
                6515329: ['Acesso_Página = 6 pontos essenciais para o sucesso de treinamento em vendas'],
                6515380: ['Acesso_Página = 7 dicas de motivação'],
                6515431: ['Acesso_Página = 7 erros que tornam'],
                6515447: ['Acesso_Página = 7 passos para evitar'],
                6515457: ['Acesso_Página = 8 Atitudes Vencedoras'],
                6515500: ['Acesso_Página =  A CNR dá mais um passo'],
                6515524: ['Acesso_Página = A Importância das lições'],
                6515546: ['Acesso_Página = ACOMAC e Sucesso em vendas']}

seg_conversão = { 6403743: ['Leads Conversão por Tráfego Direto'],
                6403748: ['Leads Conversão Email'],
                6403751: ['Leads Conversão Referência'],
                6403762: ['Leads Conversão Social'],
                6406864: ['Leads Conversão Busca Orgânica'],
                6406869: ['Leads Conversão Busca Paga'],
                6407033: ['Leads Conversão Outros'],
                6407052: ['Leads Conversão Display'],
                6407080: ['Leads Conversão Desconhecido']}

   
seg_funil = {6407127: ['Funil = Leads'],
                407130: ['Funil = Lead Qualificado'],
                6407136: ['Funil = Cliente']}

seg_email =  {6577115: ['Email_Recebeu'],
                6577122: ['Email_Não_Recebeu'],
                6578753: ['Email_Abriu'],
                6578770: ['Email_Recebeu_mas_não_Abriu'],
                6578773: ['Email_Clicou_no_Link'],
                6578778: ['Email_Recebeu_mas_não_abriu_Link']}

seg_perfil = {6513802: ['Perfil_Lead = D'],
                6513827: ['Perfil_Lead = C'],
                6513832: ['Perfil_Lead = B'],
                6569162: ['Perfil_Lead = A']}

# %%
#Todos os contatos da base.

url = "https://api.rd.services/platform/segmentations/6403772/contacts"

headers = {
    "Accept": "application/json",
    "Authorization": access_token
}
lista =[]
page = 1 
while True:
    general_response = requests.get(url, headers = headers, params = {'page': str(page), "page_size": '125'})
    r = general_response.json()
    if len(r['contacts']) == 0:
        break
    lista.append(pd.DataFrame.from_dict(r['contacts']))
    page = page + 1
all_contacts = pd.concat(lista)
all_contacts[['last_conversion_date', 'new']] = all_contacts['last_conversion_date'].str.split('T', expand=True)
all_contacts[['created_at', 'new2']] = all_contacts['created_at'].str.split('T', expand=True)
all_contacts = all_contacts.drop('new', axis = 1)
all_contacts = all_contacts.drop('new2', axis =1)
Contatos = all_contacts.to_excel('C:\\Users\\SV - João Victor\\Sucesso em Vendas\\Gestão de Resultados - Documentos\\Projetos\\02 - Report por Área\Marketing\\Power BI - Redes Sociais\\RDStation\\DIM_Contatos.xlsx')
all_contacts

# %%
#Lista com ID dos leads

uuid_list = all_contacts.copy()
columns_drop = ['name','email','last_conversion_date','created_at','links']
uuid_list = uuid_list.drop(columns_drop, axis = 1)
uuid_list = uuid_list['uuid'].to_list()
uuid_list
# Out:
# ['c982b005-c332-4a0a-b428-4a3fb2ae7c25',
#  'e5c5256c-9cfd-483f-a2bb-4d492bec82a4',
#  '9041b96e-bdd6-48b2-8b32-eada10466199',
#  'b73882a1-e13e-41a5-bfa3-a7e6f07e4960',
#  '2d74e414-338e-4505-a231-d7a62e848042',
#  '92d12b3e-8c95-4070-a07a-6944aaf03e79',
#  '85d61839-67c7-4871-8b0a-b3f80c5cccfa',
#  'ea5ace08-0ddf-48ac-8f71-e9a932a09b80',
#  '6a099c2a-fff7-4bbd-9293-11dda17ead62',
#  '100dfdc6-a9d6-42f4-9e41-d3999fce6721',
#  'ddeefae2-18ab-4b0a-a054-84fbf339986a',
#  'd3ba0b65-a86c-465b-966f-f237cd6e9c0e',
#  '6a4be408-2f59-483a-bdcd-0b9de100cf84',
#  '206e88f3-ed63-4432-b196-8c32eed2ade4',
#  'b31ea4e6-fb50-4f36-b7f8-568fe7c386c6',
#  'ca3e4122-7689-4eae-9136-8752619d9c6e',
#  'f84cc1e1-1049-421f-a36f-03f03d46a82e',
#  '06898c27-6801-453f-a5dc-8a3db7907d55',
#  'e1b06423-fa50-4f85-bc3f-97f94778e98d',
#  '918c84c5-4aa9-4114-92cc-13d85dc23ffd',
#  '7d19e97e-0fbc-4400-af52-aa69e9de00c3',
#  '588ee2dc-d3f8-4ae8-8004-5d81d6b76afb',
#  'e48db7cb-395a-4e22-bd00-01970c56620c',
# ...

# %%
#Base Segmentação Landing Page

urls = ['6514872',
 '6514880',
 '6514886',
 '6514893',
 '6514896',
 '6514915',
 '6514936',
 '6514975',
 '6514992',
 '6515104',
 '6515234',
 '6515237',
 '6515242',
 '6515274',
 '6515282',
 '6515293',
 '6515299',
 '6515313',
 '6515329',
 '6515380',
 '6515431',
 '6515447',
 '6515457',
 '6515500',
 '6515524',
 '6515546']

lista2 = []

for url in urls:
    lista =[]
    page = 1 
    while True:
        response = requests.get(url = "https://api.rd.services/platform/segmentations/"+url+"/contacts", headers = headers, params ={'page': str(page), 'page_size': 125}).json()
        if len(response['contacts']) == 0:
            break
        lista.append(pd.DataFrame.from_dict(response['contacts']))
        page = page + 1 
    if len(lista) > 0:
        base_landing = pd.concat(lista)
        rows = base_landing.shape[0]
        new_col = [url]*rows
        base_landing['ID_Landing Page'] = new_col
        lista2.append(base_landing)
    else:
        pass

base_landing = pd.concat(lista2)
base_landing[['last_conversion_date', 'new']] = base_landing['last_conversion_date'].str.split('T', expand=True)
base_landing[['created_at', 'new2']] = base_landing['created_at'].str.split('T', expand=True)
base_landing = base_landing.drop('new', axis = 1)
base_landing = base_landing.drop('new2', axis =1)
Leads_Landing_Page = base_landing.to_excel('C:\\Users\\SV - João Victor\\Sucesso em Vendas\\Gestão de Resultados - Documentos\\Projetos\\02 - Report por Área\Marketing\\Power BI - Redes Sociais\\RDStation\\Landing Page.xlsx')

# %%
#Base Segmentação Funil

urls = ['6407127',
        '6407130',
        '6407136',
        '6569162']

lista2 = []

for url in urls:
    lista =[]
    page = 1 
    while True:
        response = requests.get(url = "https://api.rd.services/platform/segmentations/"+url+"/contacts", headers = headers, params ={'page': str(page), 'page_size': 125}).json()
        if len(response['contacts']) == 0:
            break
        lista.append(pd.DataFrame.from_dict(response['contacts']))
        page = page + 1 
    if len(lista) > 0:
        base_funil = pd.concat(lista)
        rows = base_funil.shape[0]
        new_col = [url]*rows
        base_funil['ID_Landing Page'] = new_col
        lista2.append(base_funil)
    else:
        pass

base_funil = pd.concat(lista2)
base_funil[['last_conversion_date', 'new']] = base_funil['last_conversion_date'].str.split('T', expand=True)
base_funil[['created_at', 'new2']] = base_funil['created_at'].str.split('T', expand=True)
base_funil = base_funil.drop('new', axis = 1)
base_funil = base_funil.drop('new2', axis =1)
base_funil = base_funil.to_excel('C:\\Users\\SV - João Victor\\Sucesso em Vendas\\Gestão de Resultados - Documentos\\Projetos\\02 - Report por Área\Marketing\\Power BI - Redes Sociais\\RDStation\\Funil.xlsx')

# %%
#Base Segmentação Conversão

urls = ['6403743',
        '6403748',
        '6403751',
        '6403762',
        '6403766',
        '6403772',
        '6406864',
        '6406869',
        '6407033',
        '6407052',
        '6407080']

lista2 = []

for url in urls:
    lista =[]
    page = 1 
    while True:
        response = requests.get(url = "https://api.rd.services/platform/segmentations/"+url+"/contacts", headers = headers, params ={'page': str(page), 'page_size': 125}).json()
        if len(response['contacts']) == 0:
            break
        lista.append(pd.DataFrame.from_dict(response['contacts']))
        page = page + 1 
    if len(lista) > 0:
        base_conversao = pd.concat(lista)
        rows = base_conversao.shape[0]
        new_col = [url]*rows
        base_conversao['ID_Landing Page'] = new_col
        lista2.append(base_conversao)
    else:
        pass

base_conversao = pd.concat(lista2)
base_conversao[['last_conversion_date', 'new']] = base_conversao['last_conversion_date'].str.split('T', expand=True)
base_conversao[['created_at', 'new2']] = base_conversao['created_at'].str.split('T', expand=True)
base_conversao = base_conversao.drop('new', axis = 1)
base_conversao = base_conversao.drop('new2', axis =1)
base_conversao = base_conversao.to_excel('C:\\Users\\SV - João Victor\\Sucesso em Vendas\\Gestão de Resultados - Documentos\\Projetos\\02 - Report por Área\Marketing\\Power BI - Redes Sociais\\RDStation\\Conversão.xlsx')
base_conversao

# %%
#Base Segmentação Perfil

urls = ['6513802',
        '6513827',
        '6513832',
        '6569162']

lista2 = []

for url in urls:
    lista =[]
    page = 1 
    while True:
        response = requests.get(url = "https://api.rd.services/platform/segmentations/"+url+"/contacts", headers = headers, params ={'page': str(page), 'page_size': 125}).json()
        if len(response['contacts']) == 0:
            break
        lista.append(pd.DataFrame.from_dict(response['contacts']))
        page = page + 1 
    if len(lista) > 0:
        base_perfil = pd.concat(lista)
        rows = base_perfil.shape[0]
        new_col = [url]*rows
        base_perfil['ID_Landing Page'] = new_col
        lista2.append(base_perfil)
    else:
        pass

base_perfil = pd.concat(lista2)
base_perfil[['last_conversion_date', 'new']] = base_perfil['last_conversion_date'].str.split('T', expand=True)
base_perfil[['created_at', 'new2']] = base_perfil['created_at'].str.split('T', expand=True)
base_perfil = base_perfil.drop('new', axis = 1)
base_perfil = base_perfil.drop('new2', axis =1)
base_perfil = base_perfil.to_excel('C:\\Users\\SV - João Victor\\Sucesso em Vendas\\Gestão de Resultados - Documentos\\Projetos\\02 - Report por Área\Marketing\\Power BI - Redes Sociais\\RDStation\\Perfil.xlsx')

# %%
#Base Email

urls = [ '6577115',
 '6577122',
 '6578753',
 '6578770',
 '6578773',
 '6578778']

lista2 = []

for url in urls:
    lista =[]
    page = 1 
    while True:
        response = requests.get(url = "https://api.rd.services/platform/segmentations/"+url+"/contacts", headers = headers, params ={'page': str(page), 'page_size': 125}).json()
        if len(response['contacts']) == 0:
            break
        lista.append(pd.DataFrame.from_dict(response['contacts']))
        page = page + 1 
    if len(lista) > 0:
        base_email = pd.concat(lista)
        rows = base_email.shape[0]
        new_col = [url]*rows
        base_email['ID_Landing Page'] = new_col
        lista2.append(base_email)
    else:
        pass

base_email = pd.concat(lista2)
base_email[['last_conversion_date', 'new']] = base_email['last_conversion_date'].str.split('T', expand=True)
base_email[['created_at', 'new2']] = base_email['created_at'].str.split('T', expand=True)
base_email = base_email.drop('new', axis = 1)
base_email = base_email.drop('new2', axis =1)
base_email = base_email.to_excel('C:\\Users\\SV - João Victor\\Sucesso em Vendas\\Gestão de Resultados - Documentos\\Projetos\\02 - Report por Área\Marketing\\Power BI - Redes Sociais\\RDStation\\Email.xlsx')

# %%
uuid = uuid_list
types = ['CONVERSION', 'OPPORTUNITY']

lista3 = []
#for type in types:
lista2 = []
for id in uuid:
    lista =[]
    page = 1 
    while True:
        response = requests.get(url = "https://api.rd.services/platform/contacts/"+id+"/events?event_type=CONVERSION", headers = headers, params ={'page': str(page), 'page_size': 125}).json()
        if len(response) == 0:
            break
        lista.append(pd.DataFrame.from_dict(response))
        page = page + 1 
    if len(lista) > 0:
        base = pd.concat(lista)
        rows = base.shape[0]
        new_col = [id]*rows
        base['Tipo'] = new_col
        base_id = lista2.append(base)
    else:
        pass

# %%
headers = {
    "Accept": "application/json",

    "Authorization": access_token
}
params = {
    'page': '1',
    'page_size':'125' 
}
lista1 = []
id_list = uuid_list
response = requests.get(url = "https://api.rd.services/platform/contacts/e48db7cb-395a-4e22-bd00-01970c56620c/events?event_type=CONVERSION", headers = headers, params = params).json()
lista.append(pd.DataFrame.from_dict(response))
response = pd.DataFrame.from_records(response)
response
# Out:
#    event_type event_family event_identifier                event_timestamp  \
# 0  CONVERSION          CDP      Forms - AGC  2022-05-26T21:15:47.066-03:00
#
#                                              payload
# 0  {'name': 'Vinicius Santiago', 'email': 'santia...

# %%
response = requests.get(url = "https://api.rd.services/platform/contacts/e48db7cb-395a-4e22-bd00-01970c56620c/events?event_type=CONVERSION", headers = headers, params ={'page': 1, 'page_size': 125}).json()
response = pd.DataFrame.from_dict(response)
response
# Out:
#    event_type event_family event_identifier                event_timestamp  \
# 0  CONVERSION          CDP      Forms - AGC  2022-05-26T21:15:47.066-03:00
#
#                                              payload
# 0  {'name': 'Vinicius Santiago', 'email': 'santia...
